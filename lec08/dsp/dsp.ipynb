# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

markerline, stemline, baseline = plt.stem(x, y, use_line_collection=True)
plt.setp(stemline, linewidth=1)
plt.setp(markerline, markersize=2.5)
plt.show()
