# %% [markdown]
# # Hands-on 09: Factorial Experiment

# %%
import numpy as np
import pandas as df

data = df.read_csv('duration.csv')

# %%
import matplotlib.pyplot as plt

plt.hist(data['duration'])
plt.show()

# %%
import pymc3 as pm
import arviz as az

model = pm.Model()

with model:
    # b0 =
    # beta =
    # bi =
    # scale =

    rate = 1 / scale
    shape = pm.Exponential('shape', lam=0.1)

    duration = pm.Gamma('duration', alpha=shape, beta=rate, observed=data['duration'])
    trace = pm.sample(5000, chains=2, random_seed=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4_/vrr8kzqn5b9dxsprxn13022m0000gn/T/ipykernel_22761/2099966803.py in <module>
#      10     # scale =
#      11
# ---> 12     rate = 1 / scale
#      13     shape = pm.Exponential('shape', lam=0.1)
#      14
#
# NameError: name 'scale' is not defined
